# %%
import matplotlib.pyplot as plt

# %% [markdown]
# reminder:
# p-stat > 0.05  => HO true
# p-stat > 0.1  => HO true (strong)
# p-stat < 0.05 => H1 true (strong)
# p-stat < 0.01 => H1 true (very strong)

# %% [markdown]
# ## Shapiro-Wilk Test

# %% [markdown]
# H0: the sample has a Gaussian distribution.
# H1: the sample does not have a Gaussian distribution.

# %%
from scipy.stats import shapiro
data = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
stat, p = shapiro(data)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably Gaussian')
else:
	print('Probably not Gaussian')
# Out:
# stat=0.895, p=0.193
# Probably Gaussian

# %%
plt.plot(data)

# %% [markdown]
# ## Pearson correlation test

# %% [markdown]
# hypothesis on samples:
#
# Observations iid
# Observations are normally distributed
# Observations in each sample have the same variance.

# %%
from scipy.stats import pearsonr
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]
stat, p = pearsonr(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('The probability law associated to the two distributions are independent')
else:
	print('The probability law associated to the two distributions are  dependent')
# Out:
# stat=0.688, p=0.028
# The probability law associated to the two distributions are  dependent

# %%
plt.plot(data1)
plt.plot(data2)

# %% [markdown]
# ## Spearman’s Rank Correlation

# %% [markdown]
# hypothesis on observations:
#
# Observations iid
# Observations can be ranked

# %% [markdown]
# H0: the two samples are independent.
# H1: there is a dependency between the samples.

# %%
from scipy.stats import spearmanr
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]
stat, p = spearmanr(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('independent')
else:
    print('dependent')
# Out:
# stat=0.855, p=0.002
# dependent

# %% [markdown]
# ## Chi-Squared Test

# %% [markdown]
# Assumptions:
#
# Observations used in the calculation of the contingency table are independent.
# 25 or more examples in each cell of the contingency table.

# %% [markdown]
# H0: the two samples are independent.
# H1: there is a dependency between the samples.

# %%
from scipy.stats import chi2_contingency
table = [[10, 20, 30],[6,  9,  17]]
stat, p, dof, expected = chi2_contingency(table)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably independent')
else:
    print('Probably dependent')
# Out:
# stat=0.272, p=0.873
# Probably independent

# %% [markdown]
# ## Student’s t-test

# %% [markdown]
# Observations iid
# Observations in each sample are normally distributed
# Observations in each sample have the same variance

# %% [markdown]
# H0: the means of the samples are equal
# H1: the means of the samples are unequal

# %%
from scipy.stats import ttest_ind
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
stat, p = ttest_ind(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Same distribution')
else:
    print('Different distributions')
# Out:
# stat=-0.326, p=0.748
# Same distribution

# %% [markdown]
# ## ANOVA

# %% [markdown]
# Observations iid
# Observations in each sample are normally distributed
# Observations in each sample have the same variance.

# %% [markdown]
# H0: the means of the samples are equal
# H1: one or more of the means of the samples are unequal

# %%
from scipy.stats import f_oneway
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
data3 = [-0.208, 0.696, 0.928, -1.148, -0.213, 0.229, 0.137, 0.269, -0.870, -1.204]
stat, p = f_oneway(data1, data2, data3)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Same distribution')
else:
    print('Different distributions')
# Out:
# stat=0.096, p=0.908
# Same distribution

# %% [markdown]
# ## Paired Student’s t-test

# %% [markdown]
# Observations iid
# Observations in each sample are normally distributed
# Observations in each sample have the same variance
# Observations across each sample are paired

# %% [markdown]
# H0: the means of the samples are equal
# H1: the means of the samples are unequal

# %%
from scipy.stats import ttest_rel
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
stat, p = ttest_rel(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=-0.334, p=0.746
# Probably the same distribution

# %%
plt.plot(data1)
plt.plot(data2)
